# %% [markdown]
# Une présentation
# ==================
#
# Sous titre...
# ------------------
#
#
#
#  Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte Du texte.
#
# $$
# x = \sum_0^\infty u_i
# $$

# %%
a = 2
a + 2
# Out:
# 4

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.random.rand(10), np.random.rand(10), "or-")
plt.show()

# %%
5555
# Out:
# 5555
